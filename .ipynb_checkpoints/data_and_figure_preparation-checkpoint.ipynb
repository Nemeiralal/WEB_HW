# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import urllib
from citipy import citipy

output_data_file = "myData/cities.csv"

lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 615

# %%
api_key = "c2747a1a47120dfe77da0d1c5bfd583b"

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
city_data = []

print("Fetching data begins     ")
print("*****************************")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
        
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    city_url = url + "&q=" + urllib.request.pathname2url(city)

    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(city_url)

    record_count += 1

    try:
        city_weather = requests.get(city_url).json()

        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        city_data.append({"City": city,"Lat": city_lat,"Lng": city_lng, "Max Temp": city_max_temp, "Humidity": city_humidity, "Cloudiness": city_clouds, "Wind Speed": city_wind, "Country": city_country, "Date": city_date})

    except:
        print("City is not found/traceble. MOving forward to next set of latitude/longitude...")
        pass
              
print("*****************************")
print("Data Retrieval Finished      ")
print("-----------------------------")
# Out:
# Fetching data begins
# *****************************
# Processing Record 1 of Set 1 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c2747a1a47120dfe77da0d1c5bfd583b&q=kavaratti
# Processing Record 2 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c2747a1a47120dfe77da0d1c5bfd583b&q=barrow
# Processing Record 3 of Set 1 | kifri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c2747a1a47120dfe77da0d1c5bfd583b&q=kifri
# Processing Record 4 of Set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c2747a1a47120dfe77da0d1c5bfd583b&q=east%20london
# Processing Record 5 of Set 1 | monrovia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c2747a1a47120dfe77da0d1c5bfd583b&q=monrovia
# Processing Record 6 of Set 1 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c2747a1a47120dfe77da0d1c5bfd583b&q=ahipara
# ...

# %%
city_data_pd = pd.DataFrame(city_data)

lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

city_data_pd.to_csv(output_data_file, index_label="City_ID")

city_data_pd.count()
# Out:
# City          557
# Cloudiness    557
# Country       557
# Date          557
# Humidity      557
# Lat           557
# Lng           557
# Max Temp      557
# Wind Speed    557
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0    kavaratti         100      IN  1560164642        75  10.57  72.64
# 1       barrow          73      AR  1560164642        59 -38.31 -60.23
# 2        kifri           0      IQ  1560164642         8  34.69  44.96
# 3  east london           0      ZA  1560164643        46 -33.02  27.91
# 4     monrovia          75      LR  1560164643        94   6.33 -10.80
#
#    Max Temp  Wind Speed
# 0     85.58       37.04
# 1     48.86        8.39
# 2    112.76        4.70
# 3     71.60       12.75
# 4     78.80        7.72

# %% [markdown]
# ## Latitude vs Temperature Plot

# %%
plt.scatter(lats, max_temps, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("myData/City Latitude vs. Max Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(lats, humidity, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("myData/City Latitude vs. Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(lats, cloudiness, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("myData/City Latitude vs. Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(lats, wind_speed, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("myData/City Latitude vs. Wind Speed.png")

# Show plot
plt.show()
